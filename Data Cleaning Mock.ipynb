# %%
import pandas as pd

# %%
#Imports df
df = pd.read_excel('Class Evaluation Form.xlsx', sheet_name='2019')
feedback_data=df.copy()

# %%
#Rename columns used for project
column_rename={
    'Please rate the following on a scale of 1-5 (with 1 being low and 5 being high) [Was the description of the course thorough and helpful?]':'Helpful Class Description',
    'Please rate the following on a scale of 1-5 (with 1 being low and 5 being high) [Was registration easy and clear?]':'Easy, Clear Registration',
    'Please rate the following on a scale of 1-5 (with 1 being low and 5 being high) [Were the office staff friendly, helpful, and informative?]':'Office Staff Pleasentness',
    'Please rank your experience/skill level prior to taking this class.':'Pre-Class Skill Level',
    'Please rank your experience/skill level after taking this class.':'Post-Class Skill Level',
    'Overall Satisfaction with the Class':'Satsification With Class',
    'How was the length of the class?':'Class Length Rating',
    'How was the class size?':'Class Size Rating',
    'Overall satisfaction with the primary Faculty member':'Satsification With Primary Faculty',
    'Overall satisfaction with the secondary Faculty member.':'Satsification With Secondary Faculty',
    'Age':'Age',
    'Household Zip Code':'Household Zip Code',
    'Household Income':'Household Income',
    'Gender':'Gender',
    'Race, racial identity, or expression':'Race',
    'Ethnicity':'Ethnicity',
    'Education':'Education',
    'Print catalog':'Medium - Print Catalog',
    'Website':'Medium - Website',
    'In person or over the phone':'Medium - In-Person or Phone'  
}

feedback_data=feedback_data.rename(columns = column_rename)

#Select columns needed for project
columns=[
    'Helpful Class Description',
    'Easy, Clear Registration',
    'Office Staff Pleasentness',
    'Pre-Class Skill Level',
    'Post-Class Skill Level',
    'Satsification With Class',
    'Class Length Rating',
    'Class Size Rating',
    'Satsification With Primary Faculty',
    'Satsification With Secondary Faculty',
    'Age',
    'Household Zip Code',
    'Household Income',
    'Gender',
    'Race',
    'Ethnicity',
    'Education',
    'Medium - Print Catalog',
    'Medium - Website',
    'Medium - In-Person or Phone'
]

feedback_data=feedback_data[columns].copy()

# %%
#Create dictionary to recode ethnicity, race,  gender and education

ethnicity_rename={
    'Cuban':'Cuban',
    'Mexican, Mexican American, Chicano':'Mexican, Mexican American, Chicano',
    'Mexican, Mexican American, Chicano, Other Hispanic: Argentinian, Columbian, Dominican, Nicaraguan, Salvadorian, Spaniard':'Multiethnic',
    'Mexican, Mexican American, Chicano, Puetro Rican':'Multiethnic',
    'Not of Hispanic, Latino, or Spanish origin':'Not of Hispanic, Latino, or Spanish origin',
    'Not of Hispanic, Latino, or Spanish origin, Other Hispanic: Argentinian, Columbian, Dominican, Nicaraguan, Salvadorian, Spaniard':'Other Hispanic: Argentinian, Columbian, Dominican, Nicaraguan, Salvadorian, Spaniard',
    'Not of Hispanic, Latino, or Spanish origin, Prefer not to say':'Not of Hispanic, Latino, or Spanish origin',
    'Other Hispanic: Argentinean, Columbian, Dominican, Nicaraguan, Salvadorian, Spaniard':'Other Hispanic: Argentinian, Columbian, Dominican, Nicaraguan, Salvadorian, Spaniard',
    'Other Hispanic: Argentinian, Columbian, Dominican, Nicaraguan, Salvadorian, Spaniard':'Other Hispanic: Argentinian, Columbian, Dominican, Nicaraguan, Salvadorian, Spaniard',
    'Prefer not to say':'Not Specified',
    'Prefer to self-identify (please use space below)':'Other',
    'Puetro Rican':'Puetro Rican',

}


race_rename={
    'American Indian or American Native':'American Indian or American Native',
    'American Indian or American Native, Asian Indian, White or European American':'Multi-Racial',
    'American Indian or American Native, Chinese, Japanese':'Multi-Racial',
    'American Indian or American Native, White or European American':'Multi-Racial',
    'Asian Indian':'Asian Indian',
    'Asian Indian, White or European American':'Multi-Racial',
    'Black or African American':'Black or African American',
    'Black or African American, Native Hawaiian, White or European American':'Multi-Racial',
    'Black or African American, Samoan':'Multi-Racial',
    'Black or African American, White or European American':'Multi-Racial',
    'Black or African American, White or European American, Prefer to self-identify (please use space below)':'Multi-Racial',
    'Chinese':'Chinese',
    'Chinese, Other Asian: Hmong, Laotian, Thai, Pakistani, Cambodian':'Multi-Racial',
    'Chinese, Vietnamese':'Multi-Racial',
    'Chinese, White or European American':'Multi-Racial',
    'Filipino':'Filipino',
    'Filipino, White or European American':'Multi-Racial',
    'Japanese':'Japanese',
    'Japanese, Other Asian: Hmong, Laotian, Thai, Pakistani, Cambodian, White or European American':'Multi-Racial',
    'Japanese, White or European American':'Multi-Racial',
    'Japanese, White or European American, Prefer to self-identify (please use space below)':'Multi-Racial',
    'Korean':'Korean',
    'Other Asian: Hmong, Laotian, Thai, Pakistani, Cambodian':'Multi-Racial',
    'Prefer not to say':'Not Specified',
    'Prefer to self-identify (please use space below)':'Other',
    'Vietnamese':'Vietnamese',
    'Vietnamese, White or European American':'Multi-Racial',
    'White or European American':'White or European American',
    'White or European American, Prefer not to say':'White or European American',
    'White or European American, Prefer to self-identify (please use space below)':'White or European American',
}

education_rename={
    '.':'Not Specified',
    '2 years of college and and 1 year of technical school (no degree through beyond HS)':'Some College Credit, No Degree',
    '2 yr technical degree':'Trade/Technical/Vocational Training',
    '3 year Traid school grad.':'Trade/Technical/Vocational Training',
    'A.A.':"Associate's Degree",
    'AA':"Associate's Degree",
    'AA degree':"Associate's Degree",
    'AA in bio':"Associate's Degree",
    'AA in Natural Science and Math':"Associate's Degree",
    'AA in welding':"Associate's Degree",
    'always learning':'Other',
    'Art school drop out':"Associate's Degree",
    'AS':"Associate's Degree",
    "Associate's degree":"Associate's Degree",
    'Associates':"Associate's Degree",
    'Associates Degree':"Associate's Degree",
    'Associates degree, registered Nurse':"Associate's Degree",
    'attending college':'High School Diploma or Equivalent Degree',
    'Bachelor’s degree':'Bachelor’s Degree',
    'College dropout':'Some College Credit, No Degree',
    'cosmetology school and some college':'Trade/Technical/Vocational Training',
    'current student in 10th grade':'8th Grade',
    'Doctorate, PhD, or equivalent':'Doctorate, PhD, or Equivalent',
    'Finishing bachelors':'High School Diploma or Equivalent Degree',
    'High school diploma or equivalent degree':'High School Diploma or Equivalent Degree',
    'In a gap before college.':'High School Diploma or Equivalent Degree',
    'JD':'Professional Degree',
    'Less than high school diploma':'Less Than High School Diploma',
    'Life Degree.':'Other',
    'Master’s degree':'Master’s Degree',
    'Master’s student':'Master’s Degree',
    "multiple bachelor's degrees":'Bachelor’s Degree',
    'School of life':'Other',
    'Some college':'Some College Credit, No Degree',
    "Some College (junior level, but didn't complete)":"Some College Credit, No Degree",
    'Some college at Academy of Art':'Some College Credit, No Degree',
    'Still in Highschool':'8th Grade',
    'Trade School':'Trade/Technical/Vocational Training'
}


feedback_data['Ethnicity'].replace(ethnicity_rename,inplace=True)
feedback_data['Race'].replace(race_rename,inplace=True)
feedback_data['Education'].replace(education_rename,inplace=True)

#For demorgraphic data where a null value exists, inserts 'Not Specificed'
for i in ['Age','Household Zip Code','Household Income', 'Gender','Race','Ethnicity', 'Education']:
    feedback_data[i]=feedback_data[i].apply(lambda x: 'Not Specified' if pd.isnull(x) else x)

# %%
#Export data for Tableau dashboard
writer = pd.ExcelWriter('Data for Dashboard.xlsx', engine='xlsxwriter')
feedback_data.to_excel(writer, sheet_name='Sheet1')  # Default position, cell A1.
writer.save()
